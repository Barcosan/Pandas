# %% [markdown]
# # Primera clase de Pandas
#
# Estaremos hablando de **pandas** la librería de *Python*
#
# **cursiva**
#
# *italica*
#
# ***cursiva en negrita***
#
# ***

# %% [markdown]
# # Markdown
#
# ## Encabezado 2
# ### Encabezado 3
# #### Encabezado 4
#
# - lista 1
# - lista 2
# - lista 3
#
# [Más informaciones en](https://www.markdownguide.org/basic-syntax/)

# %% [markdown]
# ***

# %% [markdown]
# ## Importamos las librerías

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
matplotlib.__version__
# Out:
# '3.2.1'

# %%
np.__version__
# Out:
# '1.18.2'

# %%
# Comprobamos las versiones
pd.__version__
# Out:
# '0.23.0'

# %% [markdown]
# ## Creación de objetos
#
# Creamos una `Serie` pasaremos una serie de valores

# %%
# Pasamos una lista de valores entre corchetes [n1, n2, nx, ...]
# Que las funciones de Python llevan parentésis donde le pasamos unos parámetros podemos observarlos con MAYU + TAB

s = pd.Series([1, 3, 5, 6, 9])
s
# Out:
# 0    1
# 1    3
# 2    5
# 3    6
# 4    9
# dtype: int64

# %% [markdown]
# El resultado será una lista de valores de tipo `ENTERO` o `int64`

# %%
s1 = pd.Series([1.0, 5, 7, 0, np.nan, 11])
s1
# Out:
# 0     1.0
# 1     5.0
# 2     7.0
# 3     0.0
# 4     NaN
# 5    11.0
# dtype: float64

# %% [markdown]
# El resultado de esta segunda serie de valores será del tipo de datos `decimales` o `float64`

# %%
s2 = pd.Series(["Bob", "Marco", 7, True, 9.0, np.nan])
s2
# Out:
# 0      Bob
# 1    Marco
# 2        7
# 3     True
# 4        9
# 5      NaN
# dtype: object

# %%
nombres = ["Bob", "Marco", "Jhon", "Nicole", False]
nombres
# Out:
# ['Bob', 'Marco', 'Jhon', 'Nicole', False]

# %%
type(nombres)
# Out:
# list

# %%
# llamamos el primer resultado será con índice 0
nombres[0]
# Out:
# 'Bob'

# %%
# El tercer valor sería el índice 2
nombres[2]
# Out:
# 'Jhon'

# %%
s3 = pd.Series(nombres)
s3
# Out:
# 0       Bob
# 1     Marco
# 2      Jhon
# 3    Nicole
# 4     False
# dtype: object

# %% [markdown]
# ### Resumen:
#
# - Una serie es una lista de objetos unidimensional
# - En el caso sea númerica, tenemos una matriz, una tabla bidimensional
# - En el caso sea mixta, entonces tenemos un `dataframe` o tipo `objeto`

# %% [markdown]
# ***
#
# ### Creación de un `dataframe`

# %%
# Creamos una tabla de fechas
dates = pd.date_range(
    '20200101',
    periods=10,
    freq='M'
)
dates
# Out:
# DatetimeIndex(['2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30',
#                '2020-05-31', '2020-06-30', '2020-07-31', '2020-08-31',
#                '2020-09-30', '2020-10-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
# construimos el dataframe
df = pd.DataFrame(
    np.random.randn(10,8),
    index=dates,
    columns=list('ABCDEFGH')
)
df
# Out:
#                    A         B         C         D         E         F  \
# 2020-01-31 -0.385702 -1.707119  0.511851  0.146049  0.542037 -0.415407
# 2020-02-29  0.226818 -0.946026 -0.982451  0.413264 -0.220793 -1.569928
# 2020-03-31 -1.253948  1.391175 -0.199537 -0.761190  0.474623  0.357972
# 2020-04-30  0.232865 -0.648775 -1.141502  0.749856  1.285802 -0.564492
# 2020-05-31  0.420269  0.709554  0.127297 -0.115412 -0.003018 -0.660336
# 2020-06-30  2.587899  0.803492  0.238012  0.330129  1.846932 -0.071476
# 2020-07-31  1.052504  0.908775  0.017689  0.054407  0.926400 -0.017651
# 2020-08-31 -0.624004  2.126415  0.275771 -0.687683 -0.844267 -0.751106
# 2020-09-30  0.948611  1.238220 -0.224607  0.842772 -0.486869  0.173450
# 2020-10-31 -0.972929 -0.858961 -0.822929  1.736665 -0.513576  0.060879
#
#                    G         H
# 2020-01-31 -1.308496 -0.884677
# 2020-02-29 -0.772236  0.692063
# 2020-03-31 -0.176746  1.260548
# 2020-04-30 -0.844324 -0.899584
# 2020-05-31 -1.829390  0.694976
# 2020-06-30 -1.185325 -0.207883
# 2020-07-31 -0.050236  0.409796
# 2020-08-31 -0.743584  0.012741
# 2020-09-30  0.033969 -0.350996
# 2020-10-31  2.190316  0.435231

# %% [markdown]
# ### Otra forma de crear un dataframe
#
# es pasarle un listado de pares `clave-valor`
# El formato es un `diccionario`
# ```
# {
#     key1: val1,
#     key2: val2,
#     ...
#     keyn: valn
# }
# ```
#
# Los valores - `val` pueden ser:
#
# - numérico
# - string
# - booleano
# - vacío o nulo
# - lista de valores
# - diccionario
# - lista de diccionarios
#
# ```
# {
#   key1: [lista:
#         { key2: val2
#         }
#     ] // esto se entiende como val1
# }
# ```

# %%
df2 = pd.DataFrame(
    {
            'A' : 1.5,
            'B' : pd.Timestamp('20201110'),
            'C' : "Texto",
            'D' : True,
            'E' : np.nan,
            'F' : pd.Categorical(["ml", "dl", "ai", "pd", "np", "iu", "io", "po", "lo", "mu" ]) 
    },
    index=dates
)
df2
# Out:
#               A          B      C     D   E   F
# 2020-01-31  1.5 2020-11-10  Texto  True NaN  ml
# 2020-02-29  1.5 2020-11-10  Texto  True NaN  dl
# 2020-03-31  1.5 2020-11-10  Texto  True NaN  ai
# 2020-04-30  1.5 2020-11-10  Texto  True NaN  pd
# 2020-05-31  1.5 2020-11-10  Texto  True NaN  np
# 2020-06-30  1.5 2020-11-10  Texto  True NaN  iu
# 2020-07-31  1.5 2020-11-10  Texto  True NaN  io
# 2020-08-31  1.5 2020-11-10  Texto  True NaN  po
# 2020-09-30  1.5 2020-11-10  Texto  True NaN  lo
# 2020-10-31  1.5 2020-11-10  Texto  True NaN  mu

# %%
df3 = pd.DataFrame(
    {
            'A' : 1.5,
            'B' : pd.Timestamp('20201110'),
            'C' : "Texto",
            'D' : True,
            'E' : np.nan,
            'F' : pd.Categorical(["ml", "dl", "ai", "pd", "np", "iu", "io", "po", "lo", "mu" ]) 
    }
)
df3
# Out:
#      A          B      C     D   E   F
# 0  1.5 2020-11-10  Texto  True NaN  ml
# 1  1.5 2020-11-10  Texto  True NaN  dl
# 2  1.5 2020-11-10  Texto  True NaN  ai
# 3  1.5 2020-11-10  Texto  True NaN  pd
# 4  1.5 2020-11-10  Texto  True NaN  np
# 5  1.5 2020-11-10  Texto  True NaN  iu
# 6  1.5 2020-11-10  Texto  True NaN  io
# 7  1.5 2020-11-10  Texto  True NaN  po
# 8  1.5 2020-11-10  Texto  True NaN  lo
# 9  1.5 2020-11-10  Texto  True NaN  mu

# %%
df4 = pd.DataFrame(
    {
            'A' : 1.5,
            'B' : pd.Timestamp('20201110'),
            'C' : "Texto",
            'D' : True,
            'E' : np.nan,
            'F' : ["ml", "dl", "ai", "pd", "np", "iu", "io", "po", "lo", "mu" ]
    }
)
df4
# Out:
#      A          B      C     D   E   F
# 0  1.5 2020-11-10  Texto  True NaN  ml
# 1  1.5 2020-11-10  Texto  True NaN  dl
# 2  1.5 2020-11-10  Texto  True NaN  ai
# 3  1.5 2020-11-10  Texto  True NaN  pd
# 4  1.5 2020-11-10  Texto  True NaN  np
# 5  1.5 2020-11-10  Texto  True NaN  iu
# 6  1.5 2020-11-10  Texto  True NaN  io
# 7  1.5 2020-11-10  Texto  True NaN  po
# 8  1.5 2020-11-10  Texto  True NaN  lo
# 9  1.5 2020-11-10  Texto  True NaN  mu

# %%
# Comprobamos los datos de este dataframe
df3.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C            object
# D              bool
# E           float64
# F          category
# dtype: object

# %%
df4.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C            object
# D              bool
# E           float64
# F            object
# dtype: object

# %%
categorias = pd.Categorical([1, 5, 7, 8])
categorias
# Out:
# [1, 5, 7, 8]
# Categories (4, int64): [1, 5, 7, 8]

# %%
var_num = [1, 5, 7, 8]
var_num
# Out:
# [1, 5, 7, 8]

# %%
type(var_num)
# Out:
# list

# %%
type(categorias)
# Out:
# pandas.core.arrays.categorical.Categorical

# %%
type(df4)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Operaciones básica de los dataframes

# %%
# Observación del encabezado del dataframe
df4.head() #el resultado sería 5 primeros elementos
# Out:
#      A          B      C     D   E   F
# 0  1.5 2020-11-10  Texto  True NaN  ml
# 1  1.5 2020-11-10  Texto  True NaN  dl
# 2  1.5 2020-11-10  Texto  True NaN  ai
# 3  1.5 2020-11-10  Texto  True NaN  pd
# 4  1.5 2020-11-10  Texto  True NaN  np

# %%
df4.head(n=7) # le indicamos cuantas filas necesitamos observar
# Out:
#      A          B      C     D   E   F
# 0  1.5 2020-11-10  Texto  True NaN  ml
# 1  1.5 2020-11-10  Texto  True NaN  dl
# 2  1.5 2020-11-10  Texto  True NaN  ai
# 3  1.5 2020-11-10  Texto  True NaN  pd
# 4  1.5 2020-11-10  Texto  True NaN  np
# 5  1.5 2020-11-10  Texto  True NaN  iu
# 6  1.5 2020-11-10  Texto  True NaN  io

# %%
# Observamos las 5 últimas filas del dataframe
df.tail()
# Out:
#                    A         B         C         D         E         F  \
# 2020-06-30  2.587899  0.803492  0.238012  0.330129  1.846932 -0.071476
# 2020-07-31  1.052504  0.908775  0.017689  0.054407  0.926400 -0.017651
# 2020-08-31 -0.624004  2.126415  0.275771 -0.687683 -0.844267 -0.751106
# 2020-09-30  0.948611  1.238220 -0.224607  0.842772 -0.486869  0.173450
# 2020-10-31 -0.972929 -0.858961 -0.822929  1.736665 -0.513576  0.060879
#
#                    G         H
# 2020-06-30 -1.185325 -0.207883
# 2020-07-31 -0.050236  0.409796
# 2020-08-31 -0.743584  0.012741
# 2020-09-30  0.033969 -0.350996
# 2020-10-31  2.190316  0.435231

# %%
# Observamos los índices de los dataframes
df.index
# Out:
# DatetimeIndex(['2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30',
#                '2020-05-31', '2020-06-30', '2020-07-31', '2020-08-31',
#                '2020-09-30', '2020-10-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
df4.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df2.index
# Out:
# DatetimeIndex(['2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30',
#                '2020-05-31', '2020-06-30', '2020-07-31', '2020-08-31',
#                '2020-09-30', '2020-10-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
# Observamos las columnas
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H'], dtype='object')

# %%
df4.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='object')

# %%
df3.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='object')

# %%
# Comprobamos los estadísticos básico de un dataframe
df.describe()
# Out:
#                A          B          C          D          E          F  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.223238   0.301675  -0.220041   0.270886   0.300727  -0.345809
# std     1.132643   1.248243   0.573754   0.739704   0.869208   0.570342
# min    -1.253948  -1.707119  -1.141502  -0.761190  -0.844267  -1.569928
# 25%    -0.564428  -0.806415  -0.673349  -0.072957  -0.420350  -0.636375
# 50%     0.229841   0.756523  -0.090924   0.238089   0.235803  -0.243442
# 75%     0.816526   1.155859   0.210333   0.665708   0.830309   0.041246
# max     2.587899   2.126415   0.511851   1.736665   1.846932   0.357972
#
#                G          H
# count  10.000000  10.000000
# mean   -0.468605   0.116222
# std     1.103654   0.709592
# min    -1.829390  -0.899584
# 25%    -1.100075  -0.315218
# 50%    -0.757910   0.211269
# 75%    -0.081864   0.627855
# max     2.190316   1.260548

# %%
# Transponer un dataframe
transponer = df.T
transponer
# Out:
#    2020-01-31  2020-02-29  2020-03-31  2020-04-30  2020-05-31  2020-06-30  \
# A   -0.385702    0.226818   -1.253948    0.232865    0.420269    2.587899
# B   -1.707119   -0.946026    1.391175   -0.648775    0.709554    0.803492
# C    0.511851   -0.982451   -0.199537   -1.141502    0.127297    0.238012
# D    0.146049    0.413264   -0.761190    0.749856   -0.115412    0.330129
# E    0.542037   -0.220793    0.474623    1.285802   -0.003018    1.846932
# F   -0.415407   -1.569928    0.357972   -0.564492   -0.660336   -0.071476
# G   -1.308496   -0.772236   -0.176746   -0.844324   -1.829390   -1.185325
# H   -0.884677    0.692063    1.260548   -0.899584    0.694976   -0.207883
#
#    2020-07-31  2020-08-31  2020-09-30  2020-10-31
# A    1.052504   -0.624004    0.948611   -0.972929
# B    0.908775    2.126415    1.238220   -0.858961
# C    0.017689    0.275771   -0.224607   -0.822929
# D    0.054407   -0.687683    0.842772    1.736665
# E    0.926400   -0.844267   -0.486869   -0.513576
# F   -0.017651   -0.751106    0.173450    0.060879
# G   -0.050236   -0.743584    0.033969    2.190316
# H    0.409796    0.012741   -0.350996    0.435231

# %%
transponer.columns
# Out:
# DatetimeIndex(['2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30',
#                '2020-05-31', '2020-06-30', '2020-07-31', '2020-08-31',
#                '2020-09-30', '2020-10-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
transponer.index
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H'], dtype='object')

# %%
# Aquí tiene sentido transponer las columnas porque son muchos valores respecto a los índices
df5 = transponer.T
df5
# Out:
#                    A         B         C         D         E         F  \
# 2020-01-31 -0.385702 -1.707119  0.511851  0.146049  0.542037 -0.415407
# 2020-02-29  0.226818 -0.946026 -0.982451  0.413264 -0.220793 -1.569928
# 2020-03-31 -1.253948  1.391175 -0.199537 -0.761190  0.474623  0.357972
# 2020-04-30  0.232865 -0.648775 -1.141502  0.749856  1.285802 -0.564492
# 2020-05-31  0.420269  0.709554  0.127297 -0.115412 -0.003018 -0.660336
# 2020-06-30  2.587899  0.803492  0.238012  0.330129  1.846932 -0.071476
# 2020-07-31  1.052504  0.908775  0.017689  0.054407  0.926400 -0.017651
# 2020-08-31 -0.624004  2.126415  0.275771 -0.687683 -0.844267 -0.751106
# 2020-09-30  0.948611  1.238220 -0.224607  0.842772 -0.486869  0.173450
# 2020-10-31 -0.972929 -0.858961 -0.822929  1.736665 -0.513576  0.060879
#
#                    G         H
# 2020-01-31 -1.308496 -0.884677
# 2020-02-29 -0.772236  0.692063
# 2020-03-31 -0.176746  1.260548
# 2020-04-30 -0.844324 -0.899584
# 2020-05-31 -1.829390  0.694976
# 2020-06-30 -1.185325 -0.207883
# 2020-07-31 -0.050236  0.409796
# 2020-08-31 -0.743584  0.012741
# 2020-09-30  0.033969 -0.350996
# 2020-10-31  2.190316  0.435231

# %%
# Ordenar los valores por índices o por columnas
df5.sort_index(axis=0, ascending=False) # axis 0 serían las filas
# Out:
#                    A         B         C         D         E         F  \
# 2020-10-31 -0.972929 -0.858961 -0.822929  1.736665 -0.513576  0.060879
# 2020-09-30  0.948611  1.238220 -0.224607  0.842772 -0.486869  0.173450
# 2020-08-31 -0.624004  2.126415  0.275771 -0.687683 -0.844267 -0.751106
# 2020-07-31  1.052504  0.908775  0.017689  0.054407  0.926400 -0.017651
# 2020-06-30  2.587899  0.803492  0.238012  0.330129  1.846932 -0.071476
# 2020-05-31  0.420269  0.709554  0.127297 -0.115412 -0.003018 -0.660336
# 2020-04-30  0.232865 -0.648775 -1.141502  0.749856  1.285802 -0.564492
# 2020-03-31 -1.253948  1.391175 -0.199537 -0.761190  0.474623  0.357972
# 2020-02-29  0.226818 -0.946026 -0.982451  0.413264 -0.220793 -1.569928
# 2020-01-31 -0.385702 -1.707119  0.511851  0.146049  0.542037 -0.415407
#
#                    G         H
# 2020-10-31  2.190316  0.435231
# 2020-09-30  0.033969 -0.350996
# 2020-08-31 -0.743584  0.012741
# 2020-07-31 -0.050236  0.409796
# 2020-06-30 -1.185325 -0.207883
# 2020-05-31 -1.829390  0.694976
# 2020-04-30 -0.844324 -0.899584
# 2020-03-31 -0.176746  1.260548
# 2020-02-29 -0.772236  0.692063
# 2020-01-31 -1.308496 -0.884677

# %%
# Ordenar los valores por índices o por columnas
df5.sort_index(axis=0, ascending=True) # axis 1 serían las columnas
# Out:
#                    A         B         C         D         E         F  \
# 2020-01-31 -0.385702 -1.707119  0.511851  0.146049  0.542037 -0.415407
# 2020-02-29  0.226818 -0.946026 -0.982451  0.413264 -0.220793 -1.569928
# 2020-03-31 -1.253948  1.391175 -0.199537 -0.761190  0.474623  0.357972
# 2020-04-30  0.232865 -0.648775 -1.141502  0.749856  1.285802 -0.564492
# 2020-05-31  0.420269  0.709554  0.127297 -0.115412 -0.003018 -0.660336
# 2020-06-30  2.587899  0.803492  0.238012  0.330129  1.846932 -0.071476
# 2020-07-31  1.052504  0.908775  0.017689  0.054407  0.926400 -0.017651
# 2020-08-31 -0.624004  2.126415  0.275771 -0.687683 -0.844267 -0.751106
# 2020-09-30  0.948611  1.238220 -0.224607  0.842772 -0.486869  0.173450
# 2020-10-31 -0.972929 -0.858961 -0.822929  1.736665 -0.513576  0.060879
#
#                    G         H
# 2020-01-31 -1.308496 -0.884677
# 2020-02-29 -0.772236  0.692063
# 2020-03-31 -0.176746  1.260548
# 2020-04-30 -0.844324 -0.899584
# 2020-05-31 -1.829390  0.694976
# 2020-06-30 -1.185325 -0.207883
# 2020-07-31 -0.050236  0.409796
# 2020-08-31 -0.743584  0.012741
# 2020-09-30  0.033969 -0.350996
# 2020-10-31  2.190316  0.435231

# %%
df5.sort_values(by="D", ascending=False) # ordenamos basada en la columna D de may a men
# Out:
#                    A         B         C         D         E         F  \
# 2020-10-31 -0.972929 -0.858961 -0.822929  1.736665 -0.513576  0.060879
# 2020-09-30  0.948611  1.238220 -0.224607  0.842772 -0.486869  0.173450
# 2020-04-30  0.232865 -0.648775 -1.141502  0.749856  1.285802 -0.564492
# 2020-02-29  0.226818 -0.946026 -0.982451  0.413264 -0.220793 -1.569928
# 2020-06-30  2.587899  0.803492  0.238012  0.330129  1.846932 -0.071476
# 2020-01-31 -0.385702 -1.707119  0.511851  0.146049  0.542037 -0.415407
# 2020-07-31  1.052504  0.908775  0.017689  0.054407  0.926400 -0.017651
# 2020-05-31  0.420269  0.709554  0.127297 -0.115412 -0.003018 -0.660336
# 2020-08-31 -0.624004  2.126415  0.275771 -0.687683 -0.844267 -0.751106
# 2020-03-31 -1.253948  1.391175 -0.199537 -0.761190  0.474623  0.357972
#
#                    G         H
# 2020-10-31  2.190316  0.435231
# 2020-09-30  0.033969 -0.350996
# 2020-04-30 -0.844324 -0.899584
# 2020-02-29 -0.772236  0.692063
# 2020-06-30 -1.185325 -0.207883
# 2020-01-31 -1.308496 -0.884677
# 2020-07-31 -0.050236  0.409796
# 2020-05-31 -1.829390  0.694976
# 2020-08-31 -0.743584  0.012741
# 2020-03-31 -0.176746  1.260548

# %%
df5.sort_values(by="D", ascending=True) # ordenamos basada en la columna D de men a may
# Out:
#                    A         B         C         D         E         F  \
# 2020-03-31 -1.253948  1.391175 -0.199537 -0.761190  0.474623  0.357972
# 2020-08-31 -0.624004  2.126415  0.275771 -0.687683 -0.844267 -0.751106
# 2020-05-31  0.420269  0.709554  0.127297 -0.115412 -0.003018 -0.660336
# 2020-07-31  1.052504  0.908775  0.017689  0.054407  0.926400 -0.017651
# 2020-01-31 -0.385702 -1.707119  0.511851  0.146049  0.542037 -0.415407
# 2020-06-30  2.587899  0.803492  0.238012  0.330129  1.846932 -0.071476
# 2020-02-29  0.226818 -0.946026 -0.982451  0.413264 -0.220793 -1.569928
# 2020-04-30  0.232865 -0.648775 -1.141502  0.749856  1.285802 -0.564492
# 2020-09-30  0.948611  1.238220 -0.224607  0.842772 -0.486869  0.173450
# 2020-10-31 -0.972929 -0.858961 -0.822929  1.736665 -0.513576  0.060879
#
#                    G         H
# 2020-03-31 -0.176746  1.260548
# 2020-08-31 -0.743584  0.012741
# 2020-05-31 -1.829390  0.694976
# 2020-07-31 -0.050236  0.409796
# 2020-01-31 -1.308496 -0.884677
# 2020-06-30 -1.185325 -0.207883
# 2020-02-29 -0.772236  0.692063
# 2020-04-30 -0.844324 -0.899584
# 2020-09-30  0.033969 -0.350996
# 2020-10-31  2.190316  0.435231
